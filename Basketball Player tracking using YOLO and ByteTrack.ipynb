# %% [markdown]
# <a href="https://colab.research.google.com/github/znaamane/rnn-machine-translation-nlp-course/blob/master/Basketball%20Player%20tracking%20using%20YOLO%20and%20ByteTrack.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
